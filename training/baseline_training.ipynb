# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.utils import save_image

import timm
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
# ==========================================
# 1. CONFIGURATION
# ==========================================

# Paths
DATA_ROOT = "/kaggle/input/affectnet"
ORIGINAL_CSV = "/kaggle/input/affectnet/labels.csv"

# For Future Use
TEST_SPLIT_OUTPUT_PATH = "/kaggle/working/saved_testset.csv"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 32
LR = 1e-4

# %%
# ==========================================
# 2. DATASET CLASS
# ==========================================
class AffectNetDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.data = dataframe.reset_index(drop=True)
        self.root_dir = root_dir
        self.transform = transform
        
        if 'pth' in self.data.columns:
            self.path_col = 'pth'
        elif 'filepath' in self.data.columns:
            self.path_col = 'filepath'
        else:
            raise ValueError("CSV must contain 'pth' or 'filepath'")

        self.classes = ['anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        img_path = os.path.join(self.root_dir, row[self.path_col])
        
        try:
            img = Image.open(img_path).convert("RGB")
        except Exception:
            img = Image.new('RGB', (224, 224), (0, 0, 0)) 

        label = self.class_to_idx[row['label']]

        if self.transform:
            img = self.transform(img)

        return img, label

# %%
# ==========================================
# 3. DATA PREPARATION (FIXED TEST SET)
# ==========================================

def prepare_data():
    print(f"--- PREPARING DATA ---")
    
    def get_standard_id(path_str):
        return os.path.join(os.path.basename(os.path.dirname(path_str)), os.path.basename(path_str))

    # 1. Load Original Data
    df_original = pd.read_csv(ORIGINAL_CSV)
    if 'pth' in df_original.columns:
        df_original['unique_id'] = df_original['pth'].apply(get_standard_id)
    
    # 2. Handle Test Split (Fixed 150 per class)
    print("Generating test split (150 per class)...")
    test_df = df_original.groupby('label').sample(n=150, random_state=42)
    
    # Save the test IDs
    test_ids = test_df['unique_id'].values
    pd.DataFrame({'unique_id': test_ids}).to_csv(TEST_SPLIT_OUTPUT_PATH, index=False)
    print(f"Test Set Created: {len(test_df)} images saved to {TEST_SPLIT_OUTPUT_PATH}")
    
    # 3. Define Training Set (Remainder of Original)
    train_val_df = df_original[~df_original['unique_id'].isin(test_ids)]

    # 4. Split Train/Val (Stratified)
    print("Splitting Train/Val (Stratified)...")
    train_df, val_df = train_test_split(
        train_val_df,
        test_size=0.2,
        random_state=42,
        stratify=train_val_df['label']
    )

    return train_df, val_df, test_df

# %%
train_df, val_df, test_df = prepare_data()
# Out:
# --- PREPARING DATA ---
# Generating test split (150 per class)...
# Test Set Created: 1200 images saved to /kaggle/working/saved_testset.csv
# Splitting Train/Val (Stratified)...

# %%
# ==========================================
# 4. TRANSFORMS & LOADERS
# ==========================================
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

train_dataset = AffectNetDataset(train_df, DATA_ROOT, transform=train_transform)
val_dataset = AffectNetDataset(val_df, DATA_ROOT, transform=eval_transform)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %%
# ==========================================
# 5. MODEL SETUP
# ==========================================
model = timm.create_model("vit_base_patch16_224", pretrained=True)

# A. MLP Head
in_features = model.head.in_features
model.head = nn.Sequential(
    nn.Linear(in_features, 512),
    nn.BatchNorm1d(512),
    nn.GELU(),
    nn.Dropout(0.3),
    nn.Linear(512, len(train_dataset.classes))
)

# B. Freeze All
for param in model.parameters():
    param.requires_grad = False
    
# C. Unfreeze Head
for param in model.head.parameters():
    param.requires_grad = True

# D. Unfreeze Last 2 Blocks (Standard Baseline)
for block in model.blocks[-2:]:
    for param in block.parameters():
        param.requires_grad = True
        
if hasattr(model, 'norm'):
    for param in model.norm.parameters():
        param.requires_grad = True

model.to(DEVICE)
# Out:
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): Identity()
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Sequential(
#     (0): Linear(in_features=768, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=512, out_features=8, bias=True)
#   )
# )

# %%
def count_parameters(model):
    table = []
    total_params = 0
    trainable_params = 0
    
    print("\n--- TRAINABLE LAYERS ---")
    for name, param in model.named_parameters():
        total_params += param.numel()
        if param.requires_grad:
            table.append(name)
            trainable_params += param.numel()
            
    # Print first few and last few layers
    print(f"Total Parameters: {total_params:,}")
    print(f"Trainable Parameters: {trainable_params:,}")
    print("Sample Trainable Layers:")
    for name in table[:3]: print(f"  {name}")
    print("  ...")
    for name in table[-3:]: print(f"  {name}")

count_parameters(model)
# Out:
# --- TRAINABLE LAYERS ---
# Total Parameters: 86,197,512
# Trainable Parameters: 14,576,136
# Sample Trainable Layers:
#   blocks.10.norm1.weight
#   blocks.10.norm1.bias
#   blocks.10.attn.qkv.weight
#   ...
#   head.1.bias
#   head.4.weight
#   head.4.bias

# %%
# ==========================================
# 6. TRAINING LOOP
# ==========================================

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=LR, weight_decay=1e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)

MAX_EPOCHS = 30
PATIENCE = 5
best_acc = 0.0
trigger_times = 0
save_path = "/kaggle/working/vit_baseline_best_model.pth"

# 1. Initialize History Lists
train_loss_hist = []
train_acc_hist = []
val_loss_hist = []
val_acc_hist = []

print(f"\nTraining Started... (Classes: {train_dataset.classes})")

for epoch in range(MAX_EPOCHS):
    
    # --- TRAINING ---
    model.train()
    running_train_loss = 0
    train_correct = 0
    train_total = 0
    
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        
        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_train_loss += loss.item()
        
        # Calculate Train Accuracy
        _, preds = torch.max(outputs, 1)
        train_correct += (preds == labels).sum().item()
        train_total += labels.size(0)
        
    avg_train_loss = running_train_loss / len(train_loader)
    train_acc = 100 * train_correct / train_total
    
    # --- VALIDATION ---
    model.eval()
    running_val_loss = 0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for imgs, labels in val_loader:
            imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
            outputs = model(imgs)
            
            # Calculate Validation Loss
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            
            _, preds = torch.max(outputs, 1)
            val_correct += (preds == labels).sum().item()
            val_total += labels.size(0)
            
    avg_val_loss = running_val_loss / len(val_loader)
    val_acc = 100 * val_correct / val_total
    
    scheduler.step()

    # 2. Append Metrics to History
    train_loss_hist.append(avg_train_loss)
    train_acc_hist.append(train_acc)
    val_loss_hist.append(avg_val_loss)
    val_acc_hist.append(val_acc)
    
    # 3. Enhanced Logging
    print(f"\nEpoch [{epoch+1}/{MAX_EPOCHS}]")
    print(f"Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
    print(f"Train Acc:  {train_acc:.2f}% | Val Acc: {val_acc:.2f}%")
    
    # --- CHECKPOINT & EARLY STOPPING ---
    if val_acc > best_acc:
        print(f"--> Improvement! Saving Model...")
        best_acc = val_acc
        trigger_times = 0
        torch.save(model.state_dict(), save_path)
    else:
        trigger_times += 1
        if trigger_times >= PATIENCE:
            print(f"Stopping Early.")
            break

print(f"\nFinal Best Validation Accuracy: {best_acc:.2f}%")
print(f"Best model saved at: {save_path}")
# Out:
# Training Started... (Classes: ['anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
#
# Epoch [1/30]
# Train Loss: 1.3601 | Val Loss: 1.1971
# Train Acc:  56.86% | Val Acc: 64.28%
# --> Improvement! Saving Model...
#
# Epoch [2/30]
# Train Loss: 1.1587 | Val Loss: 1.1602
# Train Acc:  66.84% | Val Acc: 66.40%
# --> Improvement! Saving Model...
#
# Epoch [3/30]
# Train Loss: 1.0733 | Val Loss: 1.1394
# Train Acc:  70.97% | Val Acc: 67.87%
# --> Improvement! Saving Model...
#
# Epoch [4/30]
# Train Loss: 0.9938 | Val Loss: 1.1555
# Train Acc:  75.46% | Val Acc: 67.01%
#
# Epoch [5/30]
# Train Loss: 0.9077 | Val Loss: 1.1866
# Train Acc:  79.86% | Val Acc: 66.94%
#
# Epoch [6/30]
# Train Loss: 0.8077 | Val Loss: 1.1773
# Train Acc:  84.63% | Val Acc: 68.67%
# --> Improvement! Saving Model...
#
# Epoch [7/30]
# Train Loss: 0.7190 | Val Loss: 1.2373
# Train Acc:  89.39% | Val Acc: 68.09%
#
# Epoch [8/30]
# Train Loss: 0.6500 | Val Loss: 1.2537
# Train Acc:  92.94% | Val Acc: 67.64%
#
# Epoch [9/30]
# Train Loss: 0.5996 | Val Loss: 1.2571
# Train Acc:  95.30% | Val Acc: 68.42%
#
# Epoch [10/30]
# Train Loss: 0.5615 | Val Loss: 1.2728
# Train Acc:  97.11% | Val Acc: 68.81%
# --> Improvement! Saving Model...
#
# Epoch [11/30]
# Train Loss: 0.5376 | Val Loss: 1.2649
# Train Acc:  98.29% | Val Acc: 68.71%
#
# Epoch [12/30]
# Train Loss: 0.5255 | Val Loss: 1.2666
# Train Acc:  98.63% | Val Acc: 69.06%
# --> Improvement! Saving Model...
#
# Epoch [13/30]
# Train Loss: 0.5152 | Val Loss: 1.2636
# Train Acc:  99.09% | Val Acc: 68.99%
#
# Epoch [14/30]
# Train Loss: 0.5093 | Val Loss: 1.2620
# Train Acc:  99.33% | Val Acc: 69.34%
# --> Improvement! Saving Model...
#
# Epoch [15/30]
# Train Loss: 0.5073 | Val Loss: 1.2617
# Train Acc:  99.42% | Val Acc: 69.37%
# --> Improvement! Saving Model...
#
# Epoch [16/30]
# Train Loss: 0.5062 | Val Loss: 1.2618
# Train Acc:  99.49% | Val Acc: 69.04%
#
# Epoch [17/30]
# Train Loss: 0.5057 | Val Loss: 1.2604
# Train Acc:  99.51% | Val Acc: 69.39%
# --> Improvement! Saving Model...
#
# Epoch [18/30]
# Train Loss: 0.5062 | Val Loss: 1.2645
# Train Acc:  99.48% | Val Acc: 68.94%
#
# Epoch [19/30]
# Train Loss: 0.5087 | Val Loss: 1.2683
# Train Acc:  99.29% | Val Acc: 69.11%
#
# Epoch [20/30]
# Train Loss: 0.5116 | Val Loss: 1.2706
# Train Acc:  99.13% | Val Acc: 68.62%
#
# Epoch [21/30]
# Train Loss: 0.5174 | Val Loss: 1.2971
# Train Acc:  98.86% | Val Acc: 68.47%
#
# Epoch [22/30]
# Train Loss: 0.5244 | Val Loss: 1.3332
# Train Acc:  98.46% | Val Acc: 67.38%
# Stopping Early.
#
# Final Best Validation Accuracy: 69.39%
# Best model saved at: /kaggle/working/vit_baseline_best_model.pth

# %%
# ==========================================
# 7. PLOTTING
# ==========================================
print("\nGenerating Plots...")

actual_epochs = range(1, len(train_loss_hist) + 1)

# Plot 1: Training Loss
plt.figure(figsize=(10, 5))
plt.plot(actual_epochs, train_loss_hist, label='Train Loss', color='blue')
plt.title('Training Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join("/kaggle/working", "training_loss_plot.png"))
plt.show()

# Plot 2: Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(actual_epochs, val_loss_hist, label='Val Loss', color='red')
plt.title('Validation Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join("/kaggle/working", "val_loss_plot.png"))
plt.show()

# Plot 3: Accuracy (Train vs Val)
plt.figure(figsize=(10, 5))
plt.plot(actual_epochs, train_acc_hist, label='Train Acc', color='green')
plt.plot(actual_epochs, val_acc_hist, label='Val Acc', color='orange')
plt.title('Model Accuracy (Train vs Val)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)
plt.savefig(os.path.join("/kaggle/working", "accuracy_plot.png"))
plt.show()
# Out:
# Generating Plots...

# %%
# ==========================================
# 8. FINAL TEST EVALUATION (Unseen Data)
# ==========================================
print("\n" + "="*40)
print("FINAL TEST EVALUATION (Unseen Data)")
print("="*40)

# --- 1. SETUP OUTPUT DIRECTORIES ---
OUTPUT_DIR = "/kaggle/working/Inference_Results"
CORRECT_DIR = os.path.join(OUTPUT_DIR, "Correct")
INCORRECT_DIR = os.path.join(OUTPUT_DIR, "Incorrect")

os.makedirs(CORRECT_DIR, exist_ok=True)
os.makedirs(INCORRECT_DIR, exist_ok=True)

# Function to un-normalize image for saving (assuming mean=0.5, std=0.5)
def unnormalize(tensor):
    return tensor * 0.5 + 0.5

# --- 2. LOADERS AND MODEL ---
# Instantiate Test Loader
# Note: Using test_df and eval_transform from previous sections
test_dataset = AffectNetDataset(test_df, DATA_ROOT, transform=eval_transform)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# Load Best Model
checkpoint_path = "/kaggle/working/vit_baseline_best_model.pth"


if os.path.exists(checkpoint_path):
    print(f"Loading best model from: {checkpoint_path}")
    model.load_state_dict(torch.load(checkpoint_path, map_location=DEVICE))
else:
    print(f"Warning: Checkpoint not found at {checkpoint_path}. Using current model state.")

model.eval()

# Metrics Containers
correct = 0
total = 0
all_preds = []
all_targets = []

# Class-wise stats containers
num_classes = len(test_dataset.classes)
class_correct = list(0. for i in range(num_classes))
class_total = list(0. for i in range(num_classes))

# Limits to prevent saving too many files
MAX_SAVE = 250
saved_count = 0

print(f"Evaluating on {len(test_dataset)} unseen test images...")
print(f"Saving sample images to: {OUTPUT_DIR}")

with torch.no_grad():
    for batch_idx, (imgs, labels) in enumerate(test_loader):
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        outputs = model(imgs)
        _, preds = torch.max(outputs, 1)

        # Update lists for Confusion Matrix
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(labels.cpu().numpy())

        # Update Overall Accuracy stats
        correct += (preds == labels).sum().item()
        total += labels.size(0)

        # --- PER-CLASS STATS LOGIC ---
        c = (preds == labels).squeeze()
        # Handle case if batch size is 1 or squeeze reduces dimensions too much
        if c.ndim == 0:
             c = c.unsqueeze(0)

        for i in range(len(labels)):
            label = labels[i].item()
            class_correct[label] += c[i].item()
            class_total[label] += 1

        # --- SAVE IMAGES LOGIC ---
        if saved_count < MAX_SAVE:
            for i in range(len(labels)):
                if saved_count >= MAX_SAVE:
                    break

                # Get single image, label, and prediction
                img_tensor = unnormalize(imgs[i]) # Undo normalization
                true_label = test_dataset.classes[labels[i].item()]
                pred_label = test_dataset.classes[preds[i].item()]

                # Construct filename: Batch_Index_True_vs_Pred.jpg
                filename = f"B{batch_idx}_ID{i}_True_{true_label}_Pred_{pred_label}.jpg"

                if preds[i] == labels[i]:
                    save_path = os.path.join(CORRECT_DIR, filename)
                else:
                    save_path = os.path.join(INCORRECT_DIR, filename)
                
                # Check if it's a tensor on GPU, move to CPU before saving
                save_image(img_tensor.cpu(), save_path)
                saved_count += 1

# --- 3. PRINT ACCURACY ---
final_acc = 100 * correct / total
print(f"\n>>> FINAL TEST ACCURACY: {final_acc:.2f}% <<<")

# --- 4. PRINT PER-CLASS TABLE ---
print("-" * 45)
print(f"{'Class':<12} | {'Accuracy':<10} | {'Samples'}")
print("-" * 45)
for i in range(num_classes):
    if class_total[i] > 0:
        acc = 100 * class_correct[i] / class_total[i]
        print(f"{test_dataset.classes[i]:<12} | {acc:>6.2f}%    | {int(class_total[i])}")
    else:
        print(f"{test_dataset.classes[i]:<12} | {'N/A':>6}     | 0")
print("-" * 45)

# --- 5. CONFUSION MATRIX ---
print("\nGenerating Confusion Matrix...")
cm = confusion_matrix(all_targets, all_preds)
class_names = test_dataset.classes

# Plotting
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix - Test Set')
plt.savefig(os.path.join(OUTPUT_DIR, "confusion_matrix.png"))
plt.show()

# --- 6. CLASSIFICATION REPORT (Precision/Recall/F1) ---
print("\nClassification Report:")
print(classification_report(all_targets, all_preds, target_names=class_names))
# Out:
# ========================================
# FINAL TEST EVALUATION (Unseen Data)
# ========================================
# Loading best model from: /kaggle/working/vit_baseline_best_model.pth
# Evaluating on 1200 unseen test images...
# Saving sample images to: /kaggle/working/Inference_Results
#
# >>> FINAL TEST ACCURACY: 60.17% <<<
# ---------------------------------------------
# Class        | Accuracy   | Samples
# ---------------------------------------------
# anger        |  66.00%    | 150
# contempt     |  52.67%    | 150
# disgust      |  50.67%    | 150
# fear         |  60.67%    | 150
# happy        |  86.67%    | 150
# neutral      |  46.67%    | 150
# sad          |  46.00%    | 150
# surprise     |  72.00%    | 150
# ---------------------------------------------
#
# Generating Confusion Matrix...
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.59      0.66      0.62       150
#     contempt       0.56      0.53      0.54       150
#      disgust       0.50      0.51      0.50       150
#         fear       0.67      0.61      0.64       150
#        happy       0.78      0.87      0.82       150
#      neutral       0.49      0.47      0.48       150
#          sad       0.57      0.46      0.51       150
#     surprise       0.63      0.72      0.67       150
#
#     accuracy                           0.60      1200
#    macro avg       0.60      0.60      0.60      1200
# weighted avg       0.60      0.60      0.60      1200

# %%
# !zip -r /kaggle/working/Inference_Results.zip /kaggle/working/Inference_Results
# Out:
#   adding: kaggle/working/Inference_Results/ (stored 0%)
#   adding: kaggle/working/Inference_Results/Incorrect/ (stored 0%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID25_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID8_True_contempt_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID25_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID30_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID24_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID18_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID11_True_contempt_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID5_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID26_True_contempt_Pred_fear.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID22_True_anger_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID4_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID16_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID1_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID7_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID23_True_contempt_Pred_sad.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID0_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID29_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID11_True_anger_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID0_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID14_True_anger_Pred_fear.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID21_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID20_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID7_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID11_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID23_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID3_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID21_True_anger_Pred_disgust.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID24_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID20_True_contempt_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID18_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID1_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID13_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID10_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID30_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID24_True_anger_Pred_surprise.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID19_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID15_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID26_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID17_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID26_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID31_True_contempt_Pred_disgust.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID15_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID17_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID18_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID12_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID10_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID16_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID6_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID12_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID2_True_anger_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID20_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID13_True_contempt_Pred_happy.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID19_True_contempt_Pred_disgust.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID28_True_contempt_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID19_True_anger_Pred_fear.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID0_True_anger_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID15_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID31_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID22_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID4_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID6_True_contempt_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID4_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID8_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID10_True_anger_Pred_disgust.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID23_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID25_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID20_True_anger_Pred_happy.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID21_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID27_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID29_True_contempt_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID5_True_contempt_Pred_disgust.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID10_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID24_True_contempt_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID22_True_contempt_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID24_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID5_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID4_True_anger_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID14_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID0_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID9_True_anger_Pred_disgust.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID26_True_anger_Pred_sad.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID8_True_anger_Pred_fear.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID29_True_anger_Pred_sad.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID14_True_contempt_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B4_ID29_True_contempt_Pred_disgust.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID9_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B3_ID20_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B7_ID4_True_contempt_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID0_True_anger_Pred_fear.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID6_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID17_True_contempt_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID14_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID9_True_anger_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID5_True_contempt_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B1_ID26_True_anger_Pred_surprise.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B2_ID20_True_anger_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B5_ID23_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B0_ID13_True_anger_Pred_disgust.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Incorrect/B6_ID6_True_contempt_Pred_neutral.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/ (stored 0%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID28_True_anger_Pred_anger.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID6_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID9_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID30_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID24_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID4_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID4_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID5_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID9_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID23_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID25_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID11_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID17_True_anger_Pred_anger.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID9_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID5_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID27_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID15_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID30_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID19_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID2_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID9_True_anger_Pred_anger.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID7_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID14_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID3_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID27_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID11_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID23_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID12_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID0_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID27_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID1_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID11_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID29_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID19_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID18_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID26_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID20_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID23_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID22_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID31_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID7_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID31_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID5_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID22_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID2_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID2_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID7_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID23_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID6_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID28_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID11_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID10_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID14_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID30_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID18_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID25_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID17_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID16_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID2_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID27_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID3_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID0_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID5_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID15_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID14_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID24_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID26_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID17_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID6_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID24_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID9_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID3_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID15_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID1_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID30_True_anger_Pred_anger.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID12_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID10_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID31_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID18_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID18_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID14_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID2_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID19_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID10_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID29_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID1_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID1_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID19_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID13_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID2_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID2_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID7_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID6_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID17_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID18_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID1_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID16_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID7_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID21_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID21_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID13_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID12_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID16_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID15_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID11_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID21_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID13_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID8_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID25_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID16_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID3_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID20_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID28_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B5_ID27_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID22_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID12_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID8_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID4_True_anger_Pred_anger.jpg (deflated 4%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID1_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID22_True_anger_Pred_anger.jpg (deflated 3%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID8_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID30_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID28_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID0_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID16_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID28_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID3_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID13_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID31_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID27_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID25_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID25_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID16_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID19_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID15_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID3_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B7_ID12_True_contempt_Pred_contempt.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID8_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID17_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID22_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID7_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID8_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B4_ID13_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B3_ID3_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B0_ID10_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID21_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID12_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID28_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B6_ID31_True_contempt_Pred_contempt.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/Correct/B1_ID29_True_anger_Pred_anger.jpg (deflated 1%)
#   adding: kaggle/working/Inference_Results/Correct/B2_ID21_True_anger_Pred_anger.jpg (deflated 2%)
#   adding: kaggle/working/Inference_Results/confusion_matrix.png (deflated 12%)
